# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

training_set = pd.read_csv('Data/train.csv')
testing_set = pd.read_csv('Data/test.csv')

# %%
print(training_set.shape)

print(testing_set.shape)

# %%
training_set.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
testing_set.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
training_set.isna().sum()
#缺失值觀察
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# MasVnrArea       8
# ExterQual        0
# ExterCond        0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Functional       0
# Fireplaces       0
# GarageCars       0
# GarageArea       0
# ...

# %%
##training_set.LotFrontage[training_set.LotFrontage.isna()]
##尋找缺失值

# %%
target = training_set.LotFrontage
training_set.drop('LotFrontage', axis=1, inplace=True)

target = training_set.Alley
training_set.drop('Alley', axis=1, inplace=True)

target = training_set.FireplaceQu
training_set.drop('FireplaceQu', axis=1, inplace=True)

target = training_set.GarageType
training_set.drop('GarageType', axis=1, inplace=True)

target = training_set.GarageYrBlt
training_set.drop('GarageYrBlt', axis=1, inplace=True)

target = training_set.GarageFinish
training_set.drop('GarageFinish', axis=1, inplace=True)

target = training_set.GarageQual
training_set.drop('GarageQual', axis=1, inplace=True)

target = training_set.GarageCond
training_set.drop('GarageCond', axis=1, inplace=True)

target = training_set.PoolQC
training_set.drop('PoolQC', axis=1, inplace=True)

target = training_set.Fence
training_set.drop('Fence', axis=1, inplace=True)

target = training_set.MiscFeature
training_set.drop('MiscFeature', axis=1, inplace=True)

target = training_set.MasVnrType
training_set.drop('MasVnrType', axis=1, inplace=True)

target = training_set.BsmtCond
training_set.drop('BsmtCond', axis=1, inplace=True)

target = training_set.BsmtExposure
training_set.drop('BsmtExposure', axis=1, inplace=True)

target = training_set.BsmtFinType1
training_set.drop('BsmtFinType1', axis=1, inplace=True)

target = training_set.BsmtFinType2
training_set.drop('BsmtFinType2', axis=1, inplace=True)

target = training_set.Electrical
training_set.drop('Electrical', axis=1, inplace=True)

target = training_set.Exterior1st
training_set.drop('Exterior1st', axis=1, inplace=True)

target = training_set.Exterior2nd
training_set.drop('Exterior2nd', axis=1, inplace=True)

target = training_set.Foundation
training_set.drop('Foundation', axis=1, inplace=True)

target = training_set.BsmtQual
training_set.drop('BsmtQual', axis=1, inplace=True)

# %% [markdown]
# ###################

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
new_MSZoning = le.fit_transform(training_set.MSZoning)
training_set.MSZoning = new_MSZoning

# %%
new_Street = le.fit_transform(training_set.Street)
training_set.Street = new_Street

# %%
new_LotShape = le.fit_transform(training_set.LotShape)
training_set.LotShape = new_LotShape

# %%
new_LandContour = le.fit_transform(training_set.LandContour)
training_set.LandContour = new_LandContour

# %%
new_Utilities = le.fit_transform(training_set.Utilities)
training_set.Utilities = new_Utilities

# %%
new_LotConfig = le.fit_transform(training_set.LotConfig)
training_set.LotConfig = new_LotConfig

# %%
new_LandSlope = le.fit_transform(training_set.LandSlope)
training_set.LandSlope = new_LandSlope

# %%
new_Neighborhood = le.fit_transform(training_set.Neighborhood)
training_set.Neighborhood = new_Neighborhood

# %%
new_Condition1 = le.fit_transform(training_set.Condition1)
training_set.Condition1 = new_Condition1
new_Condition2 = le.fit_transform(training_set.Condition2)
training_set.Condition2 = new_Condition2
new_BldgType = le.fit_transform(training_set.BldgType)
training_set.BldgType = new_BldgType
new_HouseStyle = le.fit_transform(training_set.HouseStyle)
training_set.HouseStyle = new_HouseStyle
new_RoofStyle = le.fit_transform(training_set.RoofStyle)
training_set.RoofStyle = new_RoofStyle
new_RoofMatl = le.fit_transform(training_set.RoofMatl)
training_set.RoofMatl = new_RoofMatl

# %%
new_ExterQual = le.fit_transform(training_set.ExterQual)
training_set.ExterQual = new_ExterQual

# %%
new_ExterCond = le.fit_transform(training_set.ExterCond)
training_set.ExterCond = new_ExterCond

# %%
new_Heating = le.fit_transform(training_set.Heating)
training_set.Heating = new_Heating

# %%
new_HeatingQC = le.fit_transform(training_set.HeatingQC)
training_set.HeatingQC = new_HeatingQC

# %%
new_CentralAir = le.fit_transform(training_set.CentralAir)
training_set.CentralAir = new_CentralAir

# %%
new_KitchenQual = le.fit_transform(training_set.KitchenQual )
training_set.KitchenQual  = new_KitchenQual

# %%
new_Functional = le.fit_transform(training_set.Functional )
training_set.Functional  = new_Functional

# %%
new_PavedDrive = le.fit_transform(training_set.PavedDrive )
training_set.PavedDrive  = new_PavedDrive

# %%
new_SaleType = le.fit_transform(training_set.SaleType )
training_set.SaleType  = new_SaleType

# %%
new_SaleCondition = le.fit_transform(training_set.SaleCondition )
training_set.SaleCondition  = new_SaleCondition

# %% [markdown]
# # Training

# %%
from sklearn.model_selection import train_test_split

X_train, X_valid, y_train, y_valid = train_test_split(training_set, target, test_size=0.2, random_state= 12, shuffle=True)
print(X_train.shape,X_valid.shape)
print(y_train.shape,y_valid.shape)
# Out:
# (1168, 60) (292, 60)
# (1168,) (292,)

# %%
from sklearn.linear_model import LinearRegression   #選擇模型
from sklearn import metrics

model1 = LinearRegression()   #建立模型
model1.fit(X_train,y_train)   #訓練模型
pred = model1.predict(X_valid)   #模型預測
print('R2 score:%.2f'%metrics.r2_score(y_valid, pred))
###
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-436-0855ed93471f> in <module>()
#       3
#       4 model1 = LinearRegression()   #建立模型
# ----> 5 model1.fit(X_train,y_train)   #訓練模型
#       6 pred = model1.predict(X_valid)   #模型預測
#       7 print('R2 score:%.2f'%metrics.r2_score(y_valid, pred))
#
# /opt/conda/lib/python3.6/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...
