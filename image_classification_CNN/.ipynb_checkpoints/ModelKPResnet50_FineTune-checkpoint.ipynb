# %%
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Model, load_model
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, CSVLogger
from keras.layers import Input, Dense, Flatten
from keras.layers.convolutional import AveragePooling2D
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from keras.applications.resnet50 import ResNet50
from keras.applications.resnet50 import preprocess_input

import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import os
import math

import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn #ignore annoying warning (from sklearn and seaborn)
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'kAP_ResNet50_Pretrain.h5'
log_file = 'KAP_ResNet50_Pretrain.csv'
result_file = 'KAP_ResNet50_Pretrain.csv'
weight_file = 'resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5'

# Use ModelCheckpoint to save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)

#取得trainData
data_path = '//data/examples/may_the_4_be_with_u/where_am_i/'
trainSet = pd.DataFrame([])
# images 的路徑
path_list = os.listdir(data_path + 'train/')
for path in path_list:
    fp = []
    file_list = os.listdir(data_path + 'train/' + path + '/')
    for f in file_list:
        fp.append(data_path + 'train/' + path + '/' + f)
    trainSet = pd.concat([trainSet, pd.DataFrame({'file_path':fp, 'class':path})], ignore_index=True)

# %%
#定義目標類別
classes = ['kitchen', 'street', 'industrial', 'insidecity', 'forest', 
           'livingroom', 'opencountry', 'PARoffice', 'mountain', 'CALsuburb', 
           'coast', 'store', 'bedroom', 'tallbuilding', 'highway']

for i in range(len(classes)):
    trainSet['class'][trainSet['class'] == classes[i]] = i

# %%
img = cv2.imread(trainSet['file_path'][0])
print(img.shape)#這裡可以看到我們透過上面的程式將圖片透過imread轉成陣列(numpy)的形式`,轉成數值後才能進行分析
plt.imshow(img)#這裡則是將我們數值化後的值重新圖片化的結果
# Out:
# (220, 293, 3)

# %%
# The data, shuffled and split between train and test sets:
X_train, X_val, y_train, y_val = train_test_split(trainSet['file_path'].values, trainSet['class'].values, test_size = 0.1)

print('X_train shape:', X_train.shape)
print('X_val shape:', X_val.shape)

# Convert class vectors to categorical class matrices.
y_train = keras.utils.to_categorical(y_train, len(classes))
y_val = keras.utils.to_categorical(y_val, len(classes))
print('y_train Shape:', y_train.shape)
print('y_val Shape:', y_val.shape)
# Out:
# X_train shape: (2686,)
# X_val shape: (299,)
# y_train Shape: (2686, 15)
# y_val Shape: (299, 15)

# %%
img_x = 336
img_y = 336
img_channels = 3

base_model = ResNet50(include_top=False, weights='Pretrain/' + weight_file,
                      input_shape=(img_x, img_y, img_channels))
#接上自訂輸出
X = base_model.output
X = AveragePooling2D((2,2))(X)
X = Flatten()(X)
predictions = Dense(len(classes), activation='softmax')(X)
model = Model(inputs=base_model.input, outputs=predictions)
    
print(model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 336, 336, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 342, 342, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 168, 168, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 168, 168, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 168, 168, 64) 0           bn_conv1[0][0]
# ...

# %%
# This will do preprocessing and realtime data augmentation:
trainDatagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    zca_whitening=False,  # apply ZCA whitening
    rotation_range=20,  # randomly rotate images in the range (degrees, 0 to 180)
    width_shift_range=0.2,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.2,  # randomly shift images vertically (fraction of total height)
    horizontal_flip=True,  # randomly flip images
    vertical_flip=False)  # randomly flip images
                
def train_batch_generator(x, y, bs):
    x_train = []
    y_train = []
    while True:
        new_ind = shuffle(range(len(x)))
        x = np.take(x, new_ind, axis=0)
        y = np.take(y, new_ind, axis=0)
        for i in range(len(x)):
            img = cv2.imread(x[i])
            img = cv2.resize(img, (img_x, img_y))            
            x_train.append(img)
            y_train.append(y[i])
            if len(x_train) == bs:
                x_train = preprocess_input(np.array(x_train))
                x_batch = next(trainDatagen.flow(x_train, batch_size=bs, shuffle=False))
                y_batch = np.array(y_train).copy()
                
                x_train = []
                y_train = []
                yield x_batch, y_batch
                
def val_batch_generator(x, y, bs):
    x_val = []
    y_val = []
    while True:
        for i in range(len(x)):
            img = cv2.imread(x[i])
            img = cv2.resize(img, (img_x, img_y))            
            x_val.append(img)
            y_val.append(y[i])
            if len(x_val) == bs:
                x_val = preprocess_input(np.array(x_val))
                x_batch = x_val.copy()
                y_batch = np.array(y_val).copy()
                
                x_val = []
                y_val = []
                yield x_batch, y_batch
                
def test_batch_generator(x, bs):
    x_test = []
    while True:
        for i in range(len(x)):
            img = cv2.imread(x[i])
            img = cv2.resize(img, (img_x, img_y))            
            x_test.append(img)
            if len(x_test) == bs:
                x_test = preprocess_input(np.array(x_test))  
                x_batch = x_test.copy()
                
                x_test = []
                yield x_batch

# %%
# Let's train the model using Adam
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=0.0001),
              metrics=['accuracy'])

checkpoint = ModelCheckpoint(model_path, monitor='val_loss', save_best_only=True, verbose=1)
early_stopper = EarlyStopping(monitor='val_loss', patience=3, verbose=1)
lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1), cooldown=0, patience=1, min_lr=0.1e-8)
csv_logger = CSVLogger('Log/' + log_file)

# %%
batch_size = 16
epochs = 15

train_gen = train_batch_generator(X_train, y_train, batch_size)
val_gen = val_batch_generator(X_val, y_val, batch_size)

print('Using real-time data augmentation.')
model_history = model.fit_generator(
                        generator=train_gen, steps_per_epoch=math.ceil(len(X_train) / batch_size),
                        epochs=epochs, workers=4, shuffle=True,
                        validation_data=val_gen, validation_steps=math.ceil(len(X_val) / batch_size),                        
                        callbacks=[checkpoint, #early_stopper, 
                                   lr_reducer, csv_logger])
# Out:
# Using real-time data augmentation.
# Epoch 1/15
# 168/168 [==============================] - 67s 399ms/step - loss: 0.9739 - acc: 0.7180 - val_loss: 0.4726 - val_acc: 0.8684
#
# Epoch 00001: val_loss improved from inf to 0.47255, saving model to /home/jovyan/Kaggle/classificationbyCNN/saved_models/kAP_ResNet50_Pretrain.h5
# Epoch 2/15
# 168/168 [==============================] - 57s 337ms/step - loss: 0.3423 - acc: 0.8839 - val_loss: 0.3375 - val_acc: 0.8980
#
# Epoch 00002: val_loss improved from 0.47255 to 0.33749, saving model to /home/jovyan/Kaggle/classificationbyCNN/saved_models/kAP_ResNet50_Pretrain.h5
# Epoch 3/15
# 168/168 [==============================] - 58s 345ms/step - loss: 0.2438 - acc: 0.9249 - val_loss: 0.3141 - val_acc: 0.9145
#
# Epoch 00003: val_loss improved from 0.33749 to 0.31412, saving model to /home/jovyan/Kaggle/classificationbyCNN/saved_models/kAP_ResNet50_Pretrain.h5
# Epoch 4/15
# ...

# %%
# loading our save model
print("Loading trained model")
model = load_model(model_path)

# Score trained model.
val_gen = val_batch_generator(X_val, y_val, X_val.shape[0])
X_batch_val, y_batch_val = next(val_gen)

scores = model.evaluate(X_batch_val, y_batch_val, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Loading trained model
# 299/299 [==============================] - 4s 12ms/step
# Test loss: 0.2380370684092659
# Test accuracy: 0.9331103688897098

# %%
training_loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

plt.plot(training_loss, label="training_loss")
plt.plot(val_loss, label="validation_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Learning Curve")
plt.legend(loc='best')
plt.show()

training_acc = model_history.history['acc']
val_acc = model_history.history['val_acc']

plt.plot(training_acc, label="training_auc")
plt.plot(val_acc, label="validation_auc")
plt.xlabel("Epochs")
plt.ylabel("Auc")
plt.title("Learning Curve")
plt.legend(loc='best')
plt.show()

# %%
testfp = []
testId = []
# images 的路徑
file_list = os.listdir(data_path + 'testset/')
for f in file_list:
    testId.append(f.replace('.jpg',''))
    testfp.append(data_path + 'testset/' + f)

# %%
test_gen = test_batch_generator(testfp, batch_size)
result_pred = model.predict_generator(generator=test_gen, steps=math.ceil(len(testfp) / batch_size), verbose=1)
# Out:
# 94/94 [==============================] - 10s 106ms/step

# %%
predict = np.argmax(result_pred, axis=1)
RunResult = pd.DataFrame({'id':testId,'class':predict[:len(testfp)]})
RunResult.to_csv('Result/' + result_file, index=0)
